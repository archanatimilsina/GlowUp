# %%
import pandas as pd

#load dataset
dataset_original = pd.read_csv('./glowup1.csv')

# make the copy of original dataset
dataset = dataset_original.copy()

# %%
print(dataset.columns)
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'product_name', 'product_type', 'brand',
#        'notable_effects', 'skin_type', 'price', 'picture_src', 'description',
#        'rating'],
#       dtype='object')

# %%
columns_remove =['Unnamed: 0.1']
dataset_original.drop(columns_remove,axis=1,inplace=True)

# %%
dataset_original.to_csv("glowup.csv", index=False)
